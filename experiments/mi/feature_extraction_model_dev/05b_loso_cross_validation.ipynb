# %%
import os
import numpy as np
import pandas as pd
from scipy.signal import butter, filtfilt, iirnotch

# Configuration
BASE_PATH = '/kaggle/input/mtcaic3-phase-ii'
OUTPUT_DIR = './preprocessed'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Filter design
def design_filters(fs=250.0):
    # Bandpass 1-40 Hz
    bp_b, bp_a = butter(4, [1/(fs/2), 40/(fs/2)], btype='band')
    # Notch at 50 Hz
    notch_b, notch_a = iirnotch(50/(fs/2), Q=30)
    return bp_b, bp_a, notch_b, notch_a

# Preprocessing steps for one trial
def preprocess_trial(df):
    eeg_cols = ['FZ','C3','CZ','C4','PZ','PO7','OZ','PO8']
    motion_cols = ['AccX','AccY','AccZ','Gyro1','Gyro2','Gyro3']
    val_col = 'Validation'

    # 1) Motion artifact detection
    motion_mag = np.sqrt((df[motion_cols]**2).sum(axis=1))
    mot_thresh = np.percentile(motion_mag, 95)
    bad_mask = motion_mag > mot_thresh

    # 2) Mask EEG
    data = df[eeg_cols].copy().values
    data[bad_mask, :] = np.nan
    data[df[val_col] == 0, :] = np.nan

    # 3) Interpolation
    for ch in range(data.shape[1]):
        col = data[:, ch]
        nans = np.isnan(col)
        if nans.all():
            continue
        idx = np.arange(len(col))
        data[nans, ch] = np.interp(idx[nans], idx[~nans], col[~nans])

    # 4) Filtering
    bp_b, bp_a, notch_b, notch_a = design_filters()
    for ch in range(data.shape[1]):
        data[:, ch] = filtfilt(bp_b, bp_a, data[:, ch])
        data[:, ch] = filtfilt(notch_b, notch_a, data[:, ch])

    # 5) Baseline correction (first 0.5s)
    bs = int(0.5 * 250)
    baseline = data[:bs].mean(axis=0)
    data -= baseline
    return data

# Load index DataFrame
def load_index(fname, label_col=True):
    df = pd.read_csv(os.path.join(BASE_PATH, fname))
    cols = ['id','subject_id','task','trial_session','trial'] + (['label'] if label_col else [])
    return df[cols]

# Process a split, grouping by task
def process_split(df, has_label=True):
    data_dict = {'MI': {'X': [], 'y': []}, 'SSVEP': {'X': [], 'y': []}}
    for _, row in df.iterrows():
        # Identify folder
        idx = row['id']
        split = 'train' if idx <= 4800 else 'validation' if idx <= 4900 else 'test'
        # Load EEGdata
        path = os.path.join(BASE_PATH, row['task'], split, row['subject_id'], str(row['trial_session']), 'EEGdata.csv')
        df_eeg = pd.read_csv(path)
        # Extract correct segment
        n_samp = 2250 if row['task']=='MI' else 1750
        start = (row['trial']-1)*n_samp
        seg = df_eeg.iloc[int(start):int(start+n_samp)].reset_index(drop=True)
        proc = preprocess_trial(seg)
        data_dict[row['task']]['X'].append(proc.T)
        if has_label:
            data_dict[row['task']]['y'].append(row['label'])
    # Stack
    for t in data_dict:
        X = np.stack(data_dict[t]['X'])
        y = np.array(data_dict[t]['y']) if has_label else None
        data_dict[t]['X'] = X
        data_dict[t]['y'] = y
    return data_dict

# Execute processing and save
for fname, label_col in [('train.csv', True), ('validation.csv', True), ('test.csv', False)]:
    df_idx = load_index(fname, label_col)
    results = process_split(df_idx, label_col)
    for task, d in results.items():
        out_file = f"{os.path.splitext(fname)[0]}_{task}.npz"
        path = os.path.join(OUTPUT_DIR, out_file)
        if label_col:
            np.savez_compressed(path, X=d['X'], y=d['y'])
        else:
            np.savez_compressed(path, X=d['X'])
        print(f"Saved {out_file}: X={d['X'].shape}" + (f", y={d['y'].shape}" if d['y'] is not None else ''))
print('Preprocessing complete.')
# Out:
# Saved train_MI.npz: X=(2400, 8, 2250), y=(2400,)
# Saved train_SSVEP.npz: X=(2400, 8, 1750), y=(2400,)
# Saved validation_MI.npz: X=(50, 8, 2250), y=(50,)
# Saved validation_SSVEP.npz: X=(50, 8, 1750), y=(50,)
# Saved test_MI.npz: X=(100, 8, 2250)
# Saved test_SSVEP.npz: X=(100, 8, 1750)
# Preprocessing complete.

# %%
import os
import numpy as np
import tensorflow as tf

from sklearn.metrics import f1_score, classification_report
from mne.decoding import CSP
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger, LearningRateScheduler

# --- 0) Config ---
data_dir   = './preprocessed'
output_dir = './models3'
os.makedirs(output_dir, exist_ok=True)

eeg_indices = [1, 2, 3, 4]  # C3, CZ, C4, PZ

# --- 1) Load & filter data ---
train_npz = np.load(os.path.join(data_dir, 'train_MI.npz'))
val_npz   = np.load(os.path.join(data_dir, 'validation_MI.npz'))

X_train_all, y_train = train_npz['X'], train_npz['y']
X_val_all,   y_val   = val_npz['X'],   val_npz['y']

# Filter for EEG channels only
X_train_raw = X_train_all[:, eeg_indices, :].transpose(0, 2, 1).astype('float32')  # (n, T, 4)
X_val_raw   = X_val_all[:,   eeg_indices, :].transpose(0, 2, 1).astype('float32')  # (n, T, 4)

# --- 2) Binarize labels ---
y_train_bin = (y_train == 'Right').astype(int)
y_val_bin   = (y_val   == 'Right').astype(int)

# --- 3) CSP for models 3, 4, 5 ---
csp = CSP(n_components=4, log=False, norm_trace=False)
X_train_csp_input = X_train_raw.transpose(0, 2, 1).astype('float64').copy()  # (n, channels, time)
csp.fit(X_train_csp_input, y_train_bin)  # ← NO 'rank' argument

W = csp.filters_[:4]

def apply_csp(X):  # X: (n, T, C)
    return np.stack([W.dot(ep.T) for ep in X], axis=0)


Xtr_csp = apply_csp(X_train_raw).astype('float32')
Xvl_csp = apply_csp(X_val_raw).astype('float32')

Xtr_csp = Xtr_csp.transpose(0, 2, 1)  # (n, T, 4)
Xvl_csp = Xvl_csp.transpose(0, 2, 1)


# For 2D models
Xtr_csp_2d = Xtr_csp[..., np.newaxis]
Xvl_csp_2d = Xvl_csp[..., np.newaxis]

# --- 4) One-hot labels ---
ytr_oh = keras.utils.to_categorical(y_train_bin, 2)
yvl_oh = keras.utils.to_categorical(y_val_bin,   2)

# --- 5) Data augmentation ---
def aug_gen(X, y, seed=0, batch_size=32):
    n = X.shape[0]
    rng = np.random.RandomState(seed)
    while True:
        idx = rng.randint(0, n, batch_size)
        bx, by = X[idx].copy(), y[idx]
        bx += rng.normal(0, 0.005, bx.shape)
        yield bx, by

train_gen_raw   = aug_gen(X_train_raw,  ytr_oh, seed=0, batch_size=64)
train_gen_csp1d = aug_gen(Xtr_csp,      ytr_oh, seed=1, batch_size=64)
train_gen_csp2d = aug_gen(Xtr_csp_2d,   ytr_oh, seed=2, batch_size=64)

steps_raw   = len(X_train_raw)  // 64
steps_csp1d = len(Xtr_csp)      // 64
steps_csp2d = len(Xtr_csp_2d)   // 64

# --- 6) Cosine LR schedule ---
def cosine_lr(epoch, lr_max=5e-5, epochs=200):
    return lr_max * (1 + np.cos(np.pi * epoch / epochs)) / 2

# --- 7) F1 Score Metric ---
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        preds  = tf.argmax(y_pred, axis=1)
        labels = tf.argmax(y_true, axis=1)
        self.tp.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 1, labels == 1), tf.float32)))
        self.fp.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 1, labels == 0), tf.float32)))
        self.fn.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 0, labels == 1), tf.float32)))

    def result(self):
        p = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
        r = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        return 2 * (p * r) / (p + r + tf.keras.backend.epsilon())

    def reset_states(self):
        self.tp.assign(0.0)
        self.fp.assign(0.0)
        self.fn.assign(0.0)

# --- 8) Callback factory ---
def get_callbacks(name):
    return [
        EarlyStopping("val_f1_score", mode="max", patience=20, restore_best_weights=True),
        ModelCheckpoint(os.path.join(output_dir, f"best_{name}.h5"),
                        "val_f1_score", mode="max", save_best_only=True),
        CSVLogger(os.path.join(output_dir, f"log_{name}.csv")),
        LearningRateScheduler(cosine_lr)
    ]

# --- 9) Model Builders ---
# [All model builder functions remain unchanged — see previous message if needed.]
def build_modelA(input_shape):
    m = keras.Sequential([
        layers.Input(input_shape),
        layers.Conv1D(32, 5, activation="relu", padding="same"),
        layers.BatchNormalization(), layers.MaxPool1D(2),
        layers.Conv1D(64, 5, activation="relu", padding="same"),
        layers.BatchNormalization(), layers.MaxPool1D(2),
        layers.Conv1D(128,5,activation="relu",padding="same"),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling1D(),
        layers.Dense(64, activation="relu", 
                     kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.7),
        layers.Dense(2, activation="softmax"),
    ])
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_modelB(input_shape):
    inp = layers.Input(input_shape)
    x = inp
    for f in [16,32,64,128,256]:
        x = layers.Conv1D(f,3,activation="relu",padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPool1D(2)(x)
    x = layers.Flatten()(x)
    for u in [128,64,32]:
        x = layers.Dense(u, activation="relu",
                         kernel_regularizer=regularizers.l2(1e-4))(x)
        x = layers.Dropout(0.5)(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp, out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model1(input_shape):
    inp = layers.Input(input_shape+(1,))
    x = layers.Concatenate()([inp, inp, inp])
    x = layers.Resizing(32,32)(x)
    base = keras.applications.ResNet50(
        include_top=False, weights="imagenet",
        input_shape=(32,32,3), pooling="avg"
    )
    base.trainable = False
    x = base(x)
    x = layers.Reshape((1, x.shape[-1]))(x)
    for _ in range(7):
        x = layers.Conv1D(64,3,activation="relu",padding="same")(x)
    x = layers.MultiHeadAttention(num_heads=4,key_dim=32)(x,x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64,activation="relu")(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model2(input_shape):
    inp = layers.Input(input_shape)
    x = inp
    for _ in range(3):
        x = layers.Conv1D(32,3,activation="elu",padding="same")(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64,activation="elu")(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model3(input_shape):
    inp = layers.Input(input_shape)  # (T, F, 1)
    x = inp
    for _ in range(5):
        x = layers.Conv2D(32,(3,3),activation="relu",padding="same")(x)
    x = layers.Flatten()(x)
    for u in [128,64,32]:
        x = layers.Dense(u, activation="relu")(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model4(input_shape):
    inp = layers.Input(input_shape)
    x = inp
    for _ in range(3):
        x = layers.Conv1D(64,3,activation="relu",padding="same")(x)
    x = layers.LSTM(128)(x)
    for _ in range(4):
        x = layers.Dense(64, activation="relu")(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model5(input_shape):
    inp = layers.Input(input_shape)
    x = inp
    for _ in range(7):
        x = layers.Conv1D(64,3,activation="elu",padding="same")(x)
    x = layers.Flatten()(x)
    for _ in range(3):
        x = layers.Dense(64, activation="elu")(x)
    out = layers.Dense(2, activation="softmax")(x)
    m = models.Model(inp,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m

def build_model6(input_shape):
    C3, C4 = 0,2
    eeg_in = layers.Input(input_shape)
    c3 = layers.Lambda(lambda x: x[:,:,C3:C3+1])(eeg_in)
    c4 = layers.Lambda(lambda x: x[:,:,C4:C4+1])(eeg_in)
    def branch():
        return models.Sequential([
            layers.Conv1D(16,250,activation="relu",padding="same"),
            layers.MaxPool1D(3),
            layers.Conv1D(32,50,activation="relu",padding="same"),
            layers.GlobalAveragePooling1D()
        ])
    b3, b4 = branch()(c3), branch()(c4)
    x = layers.Concatenate()([b3,b4])
    for _ in range(4):
        x = layers.Dense(64,activation="relu")(x)
    out = layers.Dense(2,activation="softmax")(x)
    m = models.Model(eeg_in,out)
    m.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy", F1Score()])
    return m
# (You can paste model builders here unchanged if needed)

# --- 10) Train & evaluate ---
builders = {
    'oldA': build_modelA,
    'oldB': build_modelB,
    'model1': build_model1,
    'model2': build_model2,
    'model3': build_model3,
    'model4': build_model4,
    'model5': build_model5,
    'model6': build_model6,
}
# Out:
# 2025-07-23 04:59:37.534621: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753246777.720990      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753246777.773235      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Computing rank from data with rank=None
#     Using tolerance 3.2e+03 (2.2e-16 eps * 4 dim * 3.6e+18  max singular value)
#     Estimated rank (data): 4
#     data: rank 4 computed from 4 data channels with 0 projectors
# Reducing data rank from 4 -> 4
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import f1_score, classification_report
from mne.decoding import CSP
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger, LearningRateScheduler
import gc

# --- 0) Config ---
BASE_PATH = '/kaggle/input/mtcaic3-phase-ii'  # Update this path
data_dir = './preprocessed'
output_dir = './models_loso'
os.makedirs(output_dir, exist_ok=True)

eeg_indices = [1, 2, 3, 4]  # C3, CZ, C4, PZ
batch_size = 64

# --- 1) Load & prepare data ---
# Load subject information from train.csv
train_df = pd.read_csv(os.path.join(BASE_PATH, 'train.csv'))
mi_train_df = train_df[train_df['task'] == 'MI'].reset_index(drop=True)
subject_ids = mi_train_df['subject_id'].values

# Load preprocessed data
train_npz = np.load(os.path.join(data_dir, 'train_MI.npz'))
X_train_all = train_npz['X']  # (2400, 8, 2250)
y_train = train_npz['y']      # (2400,)

# Filter for EEG channels
X_train_raw = X_train_all[:, eeg_indices, :].transpose(0, 2, 1).astype('float32')  # (2400, 2250, 4)

# Binarize labels
y_train_bin = (y_train == 'Right').astype(int)

# --- 2) Setup LOSO Cross-Validation ---
logo = LeaveOneGroupOut()
groups = subject_ids
n_folds = logo.get_n_splits(groups=groups)

# --- 3) Model Builders (Unchanged from original) ---
# [Include all model builder functions: build_modelA, build_modelB, build_model1, etc.]
# ... (Paste all your model builder functions here unchanged) ...

# --- 4) F1 Score Metric (Unchanged) ---
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        preds  = tf.argmax(y_pred, axis=1)
        labels = tf.argmax(y_true, axis=1)
        self.tp.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 1, labels == 1), tf.float32)))
        self.fp.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 1, labels == 0), tf.float32)))
        self.fn.assign_add(tf.reduce_sum(tf.cast(tf.logical_and(preds == 0, labels == 1), tf.float32)))

    def result(self):
        p = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
        r = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        return 2 * (p * r) / (p + r + tf.keras.backend.epsilon())

    def reset_states(self):
        self.tp.assign(0.0)
        self.fp.assign(0.0)
        self.fn.assign(0.0)

    # ... (Paste your F1Score class implementation here) ...

# --- 5) Cosine LR Schedule (Unchanged) ---
def cosine_lr(epoch, lr_max=5e-5, epochs=200):
    return lr_max * (1 + np.cos(np.pi * epoch / epochs)) / 2

# --- 6) Callback Factory ---
def get_callbacks(name, fold_dir):
    return [
        EarlyStopping(monitor="val_f1_score", mode="max", patience=20, restore_best_weights=True),
        ModelCheckpoint(os.path.join(fold_dir, f"best_{name}.h5")),
        CSVLogger(os.path.join(fold_dir, f"log_{name}.csv")),
        LearningRateScheduler(cosine_lr)
    ]

# --- 7) Data Augmentation Generator ---
def aug_gen(X, y, seed=0, batch_size=32):
    n = X.shape[0]
    rng = np.random.RandomState(seed)
    while True:
        idx = rng.randint(0, n, batch_size)
        bx, by = X[idx].copy(), y[idx]
        bx += rng.normal(0, 0.005, bx.shape)
        yield bx, by

# --- 8) LOSO Cross-Validation ---
# Dictionary to store results
builders = {
    'oldA': build_modelA,
    'oldB': build_modelB,
    'model1': build_model1,
    'model2': build_model2,
    'model3': build_model3,
    'model4': build_model4,
    'model5': build_model5,
    'model6': build_model6,
}

# Initialize results storage
results = {name: [] for name in builders.keys()}

for fold_idx, (train_idx, val_idx) in enumerate(logo.split(X_train_raw, y_train_bin, groups=groups)):
    subject_id = groups[val_idx[0]]
    print(f"\n{'='*50}")
    print(f"Fold {fold_idx+1}/{n_folds} - Subject: {subject_id}")
    print(f"{'='*50}")
    
    # Create output directory for fold
    fold_dir = os.path.join(output_dir, f"fold_{fold_idx+1}")
    os.makedirs(fold_dir, exist_ok=True)
    
    # Split data
    X_train_fold_raw = X_train_raw[train_idx]
    y_train_fold_bin = y_train_bin[train_idx]
    X_val_fold_raw = X_train_raw[val_idx]
    y_val_fold_bin = y_train_bin[val_idx]
    
    # --- Compute CSP using ONLY training fold data ---
    print("Computing CSP for current fold...")
    csp = CSP(n_components=4, log=False, norm_trace=False)
    
    # Prepare data for CSP: (n_trials, n_channels, n_times)
    X_train_csp_input = X_train_fold_raw.transpose(0, 2, 1).astype('float64')
    csp.fit(X_train_csp_input, y_train_fold_bin)
    W = csp.filters_[:4]  # (4, 4) filter matrix
    
    # Apply CSP to both training and validation data
    def apply_csp_fold(X):
        return np.stack([W.T @ x.T for x in X], axis=0)  # (n, n_components, n_times)
    
    X_train_fold_csp = apply_csp_fold(X_train_fold_raw).transpose(0, 2, 1).astype('float32')
    X_val_fold_csp = apply_csp_fold(X_val_fold_raw).transpose(0, 2, 1).astype('float32')
    
    # Create 2D versions for models that need it
    X_train_fold_csp_2d = X_train_fold_csp[..., np.newaxis]
    X_val_fold_csp_2d = X_val_fold_csp[..., np.newaxis]
    
    # One-hot encode labels
    y_train_fold_oh = keras.utils.to_categorical(y_train_fold_bin, 2)
    y_val_fold_oh = keras.utils.to_categorical(y_val_fold_bin, 2)
    
    # Steps per epoch
    steps_per_epoch = len(X_train_fold_raw) // batch_size
    
    # --- Train all models on current fold ---
    for name, build_fn in builders.items():
        print(f"\n>>> Training {name} on Fold {fold_idx+1}")
        
        # Clean up previous models
        tf.keras.backend.clear_session()
        gc.collect()
        
        # Select appropriate data format
        if name == 'model3':
            X_train = X_train_fold_csp_2d
            X_val = X_val_fold_csp_2d
            input_shape = X_train.shape[1:]
            train_gen = aug_gen(X_train, y_train_fold_oh, seed=fold_idx, batch_size=batch_size)
        elif name in ['model4', 'model5']:
            X_train = X_train_fold_csp
            X_val = X_val_fold_csp
            input_shape = X_train.shape[1:]
            train_gen = aug_gen(X_train, y_train_fold_oh, seed=fold_idx, batch_size=batch_size)
        else:
            X_train = X_train_fold_raw
            X_val = X_val_fold_raw
            input_shape = X_train.shape[1:]
            train_gen = aug_gen(X_train, y_train_fold_oh, seed=fold_idx, batch_size=batch_size)
        
        # Build model
        model = build_fn(input_shape)
        
        # Train model
        history = model.fit(
            train_gen,
            steps_per_epoch=steps_per_epoch,
            epochs=200,
            validation_data=(X_val, y_val_fold_oh),
            callbacks=get_callbacks(name, fold_dir),
            verbose=2
        )
        
        # Evaluate
        preds = np.argmax(model.predict(X_val), axis=1)
        f1 = f1_score(y_val_fold_bin, preds)
        print(f"{name} → Fold {fold_idx+1} Val F1 = {f1:.4f}")
        results[name].append(f1)
        
        # Save fold results
        np.save(os.path.join(fold_dir, f"results_{name}.npy"), np.array([f1]))

# --- 9) Final Results ---
print("\n\n=== Final LOSO Results ===")
for name, f1_scores in results.items():
    mean_f1 = np.mean(f1_scores)
    std_f1 = np.std(f1_scores)
    print(f"{name}:")
    print(f"  F1 Scores: {', '.join([f'{s:.4f}' for s in f1_scores])}")
    print(f"  Mean F1 = {mean_f1:.4f} ± {std_f1:.4f}\n")

# Save all results
np.save(os.path.join(output_dir, "all_results.npy"), results)
print("LOSO complete!")
# Out:
# ==================================================
# Fold 1/30 - Subject: S1
# ==================================================
# Computing CSP for current fold...
# Computing rank from data with rank=None
#     Using tolerance 3.2e+03 (2.2e-16 eps * 4 dim * 3.6e+18  max singular value)
#     Estimated rank (data): 4
#     data: rank 4 computed from 4 data channels with 0 projectors
# Reducing data rank from 4 -> 4
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
#
# >>> Training oldA on Fold 1
# I0000 00:00:1753246800.576299      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753246805.840761      61 service.cc:148] XLA service 0x7913a8024d10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753246805.841518      61 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1753246806.292436      61 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1753246809.929072      61 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#
200
# 36/36 - 1s - 28ms/step - accuracy: 0.5187 - f1_score: 0.5730 - loss: 0.6955 - val_accuracy: 0.5875 - val_f1_score: 0.4923 - val_loss: 0.6975 - learning_rate: 7.3832e-04
# Epoch 26/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5582 - f1_score: 0.5885 - loss: 0.6922 - val_accuracy: 0.5375 - val_f1_score: 0.3729 - val_loss: 0.7002 - learning_rate: 7.1022e-04
# Epoch 27/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5308 - f1_score: 0.5048 - loss: 0.6932 - val_accuracy: 0.4625 - val_f1_score: 0.2456 - val_loss: 0.7002 - learning_rate: 6.8101e-04
# Epoch 28/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5430 - f1_score: 0.5459 - loss: 0.6902 - val_accuracy: 0.5250 - val_f1_score: 0.3667 - val_loss: 0.6979 - learning_rate: 6.5084e-04
# Epoch 29/200
# 36/36 - 1s - 29ms/step - accuracy: 0.5256 - f1_score: 0.5367 - loss: 0.6977 - val_accuracy: 0.4750 - val_f1_score: 0.4474 - val_loss: 0.7007 - learning_rate: 6.1987e-04
# Epoch 30/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5282 - f1_score: 0.5305 - loss: 0.6955 - val_accuracy: 0.5375 - val_f1_score: 0.3729 - val_loss: 0.6984 - learning_rate: 5.8827e-04
# Epoch 31/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5421 - f1_score: 0.5154 - loss: 0.6946 - val_accuracy: 0.5000 - val_f1_score: 0.5745 - val_loss: 0.7010 - learning_rate: 5.5621e-04
# Epoch 32/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5343 - f1_score: 0.5615 - loss: 0.6919 - val_accuracy: 0.4625 - val_f1_score: 0.5474 - val_loss: 0.7046 - learning_rate: 5.2388e-04
# Epoch 33/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5386 - f1_score: 0.5307 - loss: 0.6936 - val_accuracy: 0.5000 - val_f1_score: 0.2857 - val_loss: 0.6979 - learning_rate: 4.9148e-04
# Epoch 34/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5430 - f1_score: 0.5416 - loss: 0.6907 - val_accuracy: 0.5500 - val_f1_score: 0.3077 - val_loss: 0.6974 - learning_rate: 4.5920e-04
# Epoch 35/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5269 - f1_score: 0.5207 - loss: 0.6961 - val_accuracy: 0.5375 - val_f1_score: 0.2449 - val_loss: 0.6959 - learning_rate: 4.2723e-04
# Epoch 36/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5621 - f1_score: 0.5734 - loss: 0.6898 - val_accuracy: 0.5500 - val_f1_score: 0.4000 - val_loss: 0.6956 - learning_rate: 3.9575e-04
# Epoch 37/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5104 - f1_score: 0.5517 - loss: 0.6934 - val_accuracy: 0.5125 - val_f1_score: 0.4179 - val_loss: 0.6956 - learning_rate: 3.6494e-04
# Epoch 38/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5434 - f1_score: 0.5572 - loss: 0.6912 - val_accuracy: 0.6000 - val_f1_score: 0.5000 - val_loss: 0.6950 - learning_rate: 3.3498e-04
# Epoch 39/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5369 - f1_score: 0.5685 - loss: 0.6940 - val_accuracy: 0.6375 - val_f1_score: 0.5797 - val_loss: 0.6926 - learning_rate: 3.0602e-04
# Epoch 40/200
# 36/36 - 1s - 28ms/step - accuracy: 0.5369 - f1_score: 0.5143 - loss: 0.6942 - val_accuracy: 0.6000 - val_f1_score: 0.4286 - val_loss: 0.6921 - learning_rate: 2.7820e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step
# oldA → Fold 1 Val F1 = 0.6667
#
# >>> Training oldB on Fold 1
# Epoch 1/200
# 36/36 - 15s - 418ms/step - accuracy: 0.4948 - f1_score: 0.4733 - loss: 3.1904 - val_accuracy: 0.4500 - val_f1_score: 0.5217 - val_loss: 0.8065 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 - 1s - 36ms/step - accuracy: 0.
200
# 36/36 - 1s - 35ms/step - accuracy: 0.5091 - f1_score: 0.6041 - loss: 0.7491 - val_accuracy: 0.4500 - val_f1_score: 0.6207 - val_loss: 0.7450 - learning_rate: 5.5621e-04
# Epoch 32/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5009 - f1_score: 0.5962 - loss: 0.7482 - val_accuracy: 0.4750 - val_f1_score: 0.6316 - val_loss: 0.7446 - learning_rate: 5.2388e-04
# Epoch 33/200
# 36/36 - 1s - 36ms/step - accuracy: 0.4991 - f1_score: 0.4848 - loss: 0.7508 - val_accuracy: 0.4875 - val_f1_score: 0.0889 - val_loss: 0.7444 - learning_rate: 4.9148e-04
# Epoch 34/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5087 - f1_score: 0.5203 - loss: 0.7477 - val_accuracy: 0.5000 - val_f1_score: 0.4595 - val_loss: 0.7442 - learning_rate: 4.5920e-04
# Epoch 35/200
# 36/36 - 1s - 36ms/step - accuracy: 0.5152 - f1_score: 0.6049 - loss: 0.7487 - val_accuracy: 0.4375 - val_f1_score: 0.5872 - val_loss: 0.7441 - learning_rate: 4.2723e-04
# Epoch 36/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5169 - f1_score: 0.5827 - loss: 0.7482 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7443 - learning_rate: 3.9575e-04
# Epoch 37/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5030 - f1_score: 0.5918 - loss: 0.7482 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7443 - learning_rate: 3.6494e-04
# Epoch 38/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5182 - f1_score: 0.5946 - loss: 0.7470 - val_accuracy: 0.4875 - val_f1_score: 0.4675 - val_loss: 0.7440 - learning_rate: 3.3498e-04
# Epoch 39/200
# 36/36 - 1s - 35ms/step - accuracy: 0.4865 - f1_score: 0.5431 - loss: 0.7497 - val_accuracy: 0.4625 - val_f1_score: 0.4557 - val_loss: 0.7438 - learning_rate: 3.0602e-04
# Epoch 40/200
# 36/36 - 1s - 35ms/step - accuracy: 0.4996 - f1_score: 0.5145 - loss: 0.7500 - val_accuracy: 0.4750 - val_f1_score: 0.1250 - val_loss: 0.7436 - learning_rate: 2.7820e-04
# Epoch 41/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5109 - f1_score: 0.5606 - loss: 0.7467 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7439 - learning_rate: 2.5163e-04
# Epoch 42/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5122 - f1_score: 0.6414 - loss: 0.7457 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7442 - learning_rate: 2.2643e-04
# Epoch 43/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5208 - f1_score: 0.6561 - loss: 0.7425 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7441 - learning_rate: 2.0267e-04
# Epoch 44/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5230 - f1_score: 0.6512 - loss: 0.7431 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7441 - learning_rate: 1.8042e-04
# Epoch 45/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5135 - f1_score: 0.6415 - loss: 0.7479 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7441 - learning_rate: 1.5972e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step
# oldB → Fold 1 Val F1 = 0.6379
#
# >>> Training model1 on Fold 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/200
# 36/36 - 28s - 787ms/step - accuracy: 0.4835 - f1_score: 0.5503 - loss: 0.6943 - val_accuracy: 0.5375 - val_f1_score: 0.0000e+00 - val_loss: 0.6924 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 - 1s - 37ms/step - accuracy: 0.5074 - f1_score: 0.0105 - loss: 0.6936 - val_accuracy: 0.5375 - val_f1_score: 0.0000e+00 - val_loss: 0.6927 - learning_rate: 9.9994e-04
# Epoch 3/200
# 36/36 - 1s - 36ms/step - accuracy: 0.4918 - f1_score: 0.5875 - loss: 0.6935 - val_accuracy: 0.5375 - val_f1_score: 0.0000e+00 - val_loss: 0.6930 - learning_rate: 9.9969e-04
# Epoch 4/200
# 36/36 - 1s - 38ms/step - accuracy: 0.5035 - f1_score: 0.1662 - loss: 0.6933 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.6937 - learning_rate: 9.9914e-04
# Epoch 5/200
# 36/36 - 1s - 30ms/step - accuracy: 0.4918 - f1_score: 0.6194 - loss: 0.6933 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.6948 - learning_rate: 9.9815e-04
# Epoch 6/200
# 36/36 - 1s - 29ms/step - accuracy: 0.5130 - f1_score: 0.6781 - loss: 0.6936 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.6946 - learning_rate: 9.9661e-04
# Epoch 7/200
# 36/36 -
- learning_rate: 9.9440e-04
# Epoch 8/200
# 36/36 - 3s - 81ms/step - accuracy: 0.8503 - f1_score: 0.8471 - loss: 0.3301 - val_accuracy: 0.5750 - val_f1_score: 0.5278 - val_loss: 1.1876 - learning_rate: 9.9140e-04
# Epoch 9/200
# 36/36 - 3s - 93ms/step - accuracy: 0.8941 - f1_score: 0.8982 - loss: 0.2342 - val_accuracy: 0.5750 - val_f1_score: 0.6304 - val_loss: 1.7652 - learning_rate: 9.8749e-04
# Epoch 10/200
# 36/36 - 3s - 82ms/step - accuracy: 0.9401 - f1_score: 0.9401 - loss: 0.1320 - val_accuracy: 0.5875 - val_f1_score: 0.6207 - val_loss: 1.7437 - learning_rate: 9.8256e-04
# Epoch 11/200
# 36/36 - 3s - 81ms/step - accuracy: 0.9588 - f1_score: 0.9598 - loss: 0.1092 - val_accuracy: 0.5625 - val_f1_score: 0.5333 - val_loss: 1.9171 - learning_rate: 9.7652e-04
# Epoch 12/200
# 36/36 - 3s - 83ms/step - accuracy: 0.9774 - f1_score: 0.9781 - loss: 0.0879 - val_accuracy: 0.6125 - val_f1_score: 0.5753 - val_loss: 1.0704 - learning_rate: 9.6924e-04
# Epoch 13/200
# 36/36 - 3s - 81ms/step - accuracy: 0.9913 - f1_score: 0.9912 - loss: 0.0369 - val_accuracy: 0.5625 - val_f1_score: 0.5783 - val_loss: 1.9933 - learning_rate: 9.6066e-04
# Epoch 14/200
# 36/36 - 3s - 82ms/step - accuracy: 0.9939 - f1_score: 0.9941 - loss: 0.0244 - val_accuracy: 0.6125 - val_f1_score: 0.6076 - val_loss: 1.7694 - learning_rate: 9.5068e-04
# Epoch 15/200
# 36/36 - 3s - 87ms/step - accuracy: 0.9935 - f1_score: 0.9934 - loss: 0.0282 - val_accuracy: 0.6500 - val_f1_score: 0.6500 - val_loss: 2.8125 - learning_rate: 9.3923e-04
# Epoch 16/200
# 36/36 - 3s - 82ms/step - accuracy: 0.9948 - f1_score: 0.9949 - loss: 0.0185 - val_accuracy: 0.5750 - val_f1_score: 0.5750 - val_loss: 2.7054 - learning_rate: 9.2626e-04
# Epoch 17/200
# 36/36 - 3s - 84ms/step - accuracy: 0.9965 - f1_score: 0.9965 - loss: 0.0125 - val_accuracy: 0.5500 - val_f1_score: 0.5610 - val_loss: 3.0408 - learning_rate: 9.1171e-04
# Epoch 18/200
# 36/36 - 3s - 81ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 0.0023 - val_accuracy: 0.5375 - val_f1_score: 0.5542 - val_loss: 4.1698 - learning_rate: 8.9555e-04
# Epoch 19/200
# 36/36 - 3s - 81ms/step - accuracy: 0.9996 - f1_score: 0.9996 - loss: 0.0022 - val_accuracy: 0.5625 - val_f1_score: 0.5679 - val_loss: 5.0646 - learning_rate: 8.7777e-04
# Epoch 20/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 5.0132e-04 - val_accuracy: 0.5750 - val_f1_score: 0.5854 - val_loss: 4.8922 - learning_rate: 8.5837e-04
# Epoch 21/200
# 36/36 - 3s - 81ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 5.8915e-04 - val_accuracy: 0.6125 - val_f1_score: 0.6173 - val_loss: 5.5775 - learning_rate: 8.3736e-04
# Epoch 22/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 6.3252e-04 - val_accuracy: 0.5625 - val_f1_score: 0.5205 - val_loss: 5.1818 - learning_rate: 8.1479e-04
# Epoch 23/200
# 36/36 - 3s - 81ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 6.2178e-04 - val_accuracy: 0.5500 - val_f1_score: 0.5263 - val_loss: 5.2624 - learning_rate: 7.9071e-04
# Epoch 24/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 4.0669e-04 - val_accuracy: 0.5500 - val_f1_score: 0.5500 - val_loss: 5.2819 - learning_rate: 7.6518e-04
# Epoch 25/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 3.5442e-04 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 5.8092 - learning_rate: 7.3832e-04
# Epoch 26/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 7.6894e-05 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 5.8881 - learning_rate: 7.1022e-04
# Epoch 27/200
# 36/36 - 3s - 81ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 5.9367e-05 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 5.9432 - learning_rate: 6.8101e-04
# Epoch 28/200
# 36/36 - 3s - 83ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 4.4200e-05 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 6.0748 - learning_rate: 6.5084e-04
# Epoch 29/200
# 36/36 - 3s - 83ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 4.3089e-05 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 6.1713 - learning_rate: 6.1987e-04
# Epoch 30/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 3.6012e-05 - val_accuracy: 0.5500 - val_f1_score: 0.5263 - val_loss: 6.2572 - learning_rate: 5.8827e-04
# Epoch 31/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 3.0056e-05 - val_accuracy: 0.5375 - val_f1_score: 0.5195 - val_loss: 6.2799 - learning_rate: 5.5621e-04
# Epoch 32/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 1.9268e-05 - val_accuracy: 0.5500 - val_f1_score: 0.5385 - val_loss: 6.3428 - learning_rate: 5.2388e-04
# Epoch 33/200
# 36/36 - 3s - 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 2.4104e-05 - val_accuracy: 0.5500 - val_f1_score: 0.5385 - val_loss: 6.3814 - learning_rate: 4.9148e-04
# Epoch 34/200
# 36/36 - 3s - 86ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 2.2610e-05 - val_accuracy: 0.5500 - val_f1_score: 0.5385 - val_loss: 6.4404 - learning_rate: 4.5920e-04
# Epoch 35/200
# 36/36 - 3s - 85ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 1.8586e-05 - val_accuracy: 0.5500 - val_f1_score: 0.5385 - val_loss: 6.4716 - learning_rate: 4.2723e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# model3 → Fold 1 Val F1 = 0.6500
#
# >>> Training model4 on Fold 1
# Epoch 1/200
# 36/36 - 10s - 277ms/step - accuracy: 0.5165 - f1_score: 0.5709 - loss: 0.6914 - val_accuracy: 0.5000 - val_f1_score: 0.6154 - val_loss: 0.6874 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5286 - f1_score: 0.4764 - loss: 0.6924 - val_accuracy: 0.5875 - val_f1_score: 0.5926 - val_loss: 0.6848 - learning_rate: 9.9994e-04
# Epoch 3/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5200 - f1_score: 0.4973 - loss: 0.6917 - val_accuracy: 0.5625 - val_f1_score: 0.4615 - val_loss: 0.6841 - learning_rate: 9.9969e-04
# Epoch 4/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5104 - f1_score: 0.4019 - loss: 0.6927 - val_accuracy: 0.6250 - val_f1_score: 0.4643 - val_loss: 0.6880 - learning_rate: 9.9914e-04
# Epoch 5/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5304 - f1_score: 0.5086 - loss: 0.6913 - val_accuracy: 0.5625 - val_f1_score: 0.6729 - val_loss: 0.6867 - learning_rate: 9.9815e-04
# Epoch 6/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5156 - f1_score: 0.4785 - loss: 0.6901 - val_accuracy: 0.6000 - val_f1_score: 0.6800 - val_loss: 0.6832 - learning_rate: 9.9661e-04
# Epoch 7/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5503 - f1_score: 0.5181 - loss: 0.6887 - val_accuracy: 0.5750 - val_f1_score: 0.4848 - val_loss: 0.6812 - learning_rate: 9.9440e-04
# Epoch 8/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5460 - f1_score: 0.4370 - loss: 0.6881 - val_accuracy: 0.5750 - val_f1_score: 0.4516 - val_loss: 0.6825 - learning_rate: 9.9140e-04
# Epoch 9/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5204 - f1_score: 0.4325 - loss: 0.6927 - val_accuracy: 0.6250 - val_f1_score: 0.6429 - val_loss: 0.6832 - learning_rate: 9.8749e-04
# Epoch 10/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5178 - f1_score: 0.2488 - loss: 0.6920 - val_accuracy: 0.6250 - val_f1_score: 0.5588 - val_loss: 0.6879 - learning_rate: 9.8256e-04
# Epoch 11/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5412 - f1_score: 0.4896 - loss: 0.6900 - val_accuracy: 0.6500 - val_f1_score: 0.6410 - val_loss: 0.6834 - learning_rate: 9.7652e-04
# Epoch 12/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5503 - f1_score: 0.5460 - loss: 0.6866 - val_accuracy: 0.5750 - val_f1_score: 0.6531 - val_loss: 0.6819 - learning_rate: 9.6924e-04
# Epoch 13/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5360 - f1_score: 0.4268 - loss: 0.6894 - val_accuracy: 0.6000 - val_f1_score: 0.5429 - val_loss: 0.6865 - learning_rate: 9.6066e-04
# Epoch 14/200
# 36/36 - 4s - 119ms/step - accuracy: 0.5343 - f1_score: 0.4903 - loss: 0.6875 - val_accuracy: 0.6500 - val_f1_score: 0.6216 - val_loss: 0.6869 - learning_rate: 9.5068e-04
# Epoch 15/200
# 36/36 - 4s - 119ms/step - accuracy: 0.
- learning_rate: 9.9440e-04
# Epoch 8/200
# 36/36 - 1s - 32ms/step - accuracy: 0.7348 - f1_score: 0.7239 - loss: 0.5230 - val_accuracy: 0.5125 - val_f1_score: 0.5895 - val_loss: 0.9923 - learning_rate: 9.9140e-04
# Epoch 9/200
# 36/36 - 1s - 31ms/step - accuracy: 0.8003 - f1_score: 0.8080 - loss: 0.4276 - val_accuracy: 0.5125 - val_f1_score: 0.4658 - val_loss: 0.9925 - learning_rate: 9.8749e-04
# Epoch 10/200
# 36/36 - 1s - 33ms/step - accuracy: 0.8325 - f1_score: 0.8348 - loss: 0.3511 - val_accuracy: 0.5250 - val_f1_score: 0.5581 - val_loss: 1.2366 - learning_rate: 9.8256e-04
# Epoch 11/200
# 36/36 - 1s - 33ms/step - accuracy: 0.8815 - f1_score: 0.8849 - loss: 0.2984 - val_accuracy: 0.4875 - val_f1_score: 0.5393 - val_loss: 1.3542 - learning_rate: 9.7652e-04
# Epoch 12/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9162 - f1_score: 0.9178 - loss: 0.2159 - val_accuracy: 0.5250 - val_f1_score: 0.5581 - val_loss: 1.6588 - learning_rate: 9.6924e-04
# Epoch 13/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9384 - f1_score: 0.9376 - loss: 0.1681 - val_accuracy: 0.5250 - val_f1_score: 0.5581 - val_loss: 1.9249 - learning_rate: 9.6066e-04
# Epoch 14/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9605 - f1_score: 0.9619 - loss: 0.1159 - val_accuracy: 0.5625 - val_f1_score: 0.6154 - val_loss: 1.9743 - learning_rate: 9.5068e-04
# Epoch 15/200
# 36/36 - 1s - 33ms/step - accuracy: 0.9666 - f1_score: 0.9662 - loss: 0.0929 - val_accuracy: 0.5000 - val_f1_score: 0.5556 - val_loss: 2.2526 - learning_rate: 9.3923e-04
# Epoch 16/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9796 - f1_score: 0.9800 - loss: 0.0720 - val_accuracy: 0.5125 - val_f1_score: 0.5412 - val_loss: 2.2116 - learning_rate: 9.2626e-04
# Epoch 17/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9835 - f1_score: 0.9833 - loss: 0.0492 - val_accuracy: 0.5500 - val_f1_score: 0.6000 - val_loss: 2.4617 - learning_rate: 9.1171e-04
# Epoch 18/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9861 - f1_score: 0.9865 - loss: 0.0379 - val_accuracy: 0.5500 - val_f1_score: 0.6000 - val_loss: 2.7482 - learning_rate: 8.9555e-04
# Epoch 19/200
# 36/36 - 1s - 33ms/step - accuracy: 0.9783 - f1_score: 0.9788 - loss: 0.0631 - val_accuracy: 0.5250 - val_f1_score: 0.5778 - val_loss: 2.5418 - learning_rate: 8.7777e-04
# Epoch 20/200
# 36/36 - 1s - 36ms/step - accuracy: 0.9727 - f1_score: 0.9737 - loss: 0.0741 - val_accuracy: 0.5125 - val_f1_score: 0.5517 - val_loss: 2.5107 - learning_rate: 8.5837e-04
# Epoch 21/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9510 - f1_score: 0.9499 - loss: 0.1492 - val_accuracy: 0.5000 - val_f1_score: 0.5745 - val_loss: 3.5507 - learning_rate: 8.3736e-04
# Epoch 22/200
# 36/36 - 1s - 32ms/step - accuracy: 0.8815 - f1_score: 0.8806 - loss: 0.3459 - val_accuracy: 0.5250 - val_f1_score: 0.5476 - val_loss: 2.0509 - learning_rate: 8.1479e-04
# Epoch 23/200
# 36/36 - 1s - 33ms/step - accuracy: 0.9240 - f1_score: 0.9251 - loss: 0.2643 - val_accuracy: 0.5375 - val_f1_score: 0.4789 - val_loss: 2.4006 - learning_rate: 7.9071e-04
# Epoch 24/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9670 - f1_score: 0.9683 - loss: 0.1074 - val_accuracy: 0.5375 - val_f1_score: 0.5747 - val_loss: 2.5025 - learning_rate: 7.6518e-04
# Epoch 25/200
# 36/36 - 1s - 32ms/step - accuracy: 0.9861 - f1_score: 0.9860 - loss: 0.0511 - val_accuracy: 0.5500 - val_f1_score: 0.5263 - val_loss: 2.5801 - learning_rate: 7.3832e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step
# model5 → Fold 1 Val F1 = 0.6606
#
# >>> Training model6 on Fold 1
# Epoch 1/200
# 36/36 - 8s - 228ms/step - accuracy: 0.5139 - f1_score: 0.5387 - loss: 3.2880 - val_accuracy: 0.5500 - val_f1_score: 0.2174 - val_loss: 1.6052 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 -
- learning_rate: 7.9071e-04
# Epoch 24/200
# 36/36 - 1s - 39ms/step - accuracy: 0.4965 - f1_score: 0.4784 - loss: 0.7015 - val_accuracy: 0.4625 - val_f1_score: 0.6126 - val_loss: 0.6945 - learning_rate: 7.6518e-04
# Epoch 25/200
# 36/36 - 1s - 39ms/step - accuracy: 0.5017 - f1_score: 0.5915 - loss: 0.7044 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7001 - learning_rate: 7.3832e-04
# Epoch 26/200
# 36/36 - 1s - 39ms/step - accuracy: 0.5022 - f1_score: 0.5366 - loss: 0.6977 - val_accuracy: 0.4500 - val_f1_score: 0.3529 - val_loss: 0.6980 - learning_rate: 7.1022e-04
# Epoch 27/200
# 36/36 - 1s - 40ms/step - accuracy: 0.5122 - f1_score: 0.5313 - loss: 0.6984 - val_accuracy: 0.4500 - val_f1_score: 0.6000 - val_loss: 0.7135 - learning_rate: 6.8101e-04
# Epoch 28/200
# 36/36 - 1s - 39ms/step - accuracy: 0.5139 - f1_score: 0.5594 - loss: 0.6951 - val_accuracy: 0.5250 - val_f1_score: 0.6481 - val_loss: 0.7487 - learning_rate: 6.5084e-04
# Epoch 29/200
# 36/36 - 1s - 40ms/step - accuracy: 0.5104 - f1_score: 0.5175 - loss: 0.7033 - val_accuracy: 0.4625 - val_f1_score: 0.6325 - val_loss: 0.7238 - learning_rate: 6.1987e-04
# Epoch 30/200
# 36/36 - 1s - 39ms/step - accuracy: 0.4944 - f1_score: 0.5281 - loss: 0.7004 - val_accuracy: 0.5250 - val_f1_score: 0.5366 - val_loss: 0.6930 - learning_rate: 5.8827e-04
# Epoch 31/200
# 36/36 - 1s - 39ms/step - accuracy: 0.5221 - f1_score: 0.5418 - loss: 0.6942 - val_accuracy: 0.5625 - val_f1_score: 0.5455 - val_loss: 0.6873 - learning_rate: 5.5621e-04
# Epoch 32/200
# 36/36 - 1s - 39ms/step - accuracy: 0.5087 - f1_score: 0.5508 - loss: 0.6994 - val_accuracy: 0.5375 - val_f1_score: 0.0000e+00 - val_loss: 0.6942 - learning_rate: 5.2388e-04
# Epoch 33/200
# ...
# Epoch 41/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5039 - f1_score: 0.6460 - loss: 0.7525 - val_accuracy: 0.5125 - val_f1_score: 0.6777 - val_loss: 0.7433 - learning_rate: 2.5163e-04
# Epoch 42/200
# 36/36 - 1s - 36ms/step - accuracy: 0.5061 - f1_score: 0.6589 - loss: 0.7502 - val_accuracy: 0.5125 - val_f1_score: 0.6777 - val_loss: 0.7444 - learning_rate: 2.2643e-04
# Epoch 43/200
# 36/36 - 1s - 36ms/step - accuracy: 0.4931 - f1_score: 0.5970 - loss: 0.7462 - val_accuracy: 0.4750 - val_f1_score: 0.0000e+00 - val_loss: 0.7448 - learning_rate: 2.0267e-04
# Epoch 44/200
# 36/36 - 1s - 36ms/step - accuracy: 0.5017 - f1_score: 0.5299 - loss: 0.7442 - val_accuracy: 0.4750 - val_f1_score: 0.5435 - val_loss: 0.7443 - learning_rate: 1.8042e-04
# Epoch 45/200
# 36/36 - 1s - 35ms/step - accuracy: 0.5030 - f1_score: 0.6461 - loss: 0.7514 - val_accuracy: 0.5125 - val_f1_score: 0.6777 - val_loss: 0.7438 - learning_rate: 1.5972e-04
# Epoch 46/200
# 36/36 - 1s - 36ms/step - accuracy: 0.5174 - f1_score: 0.6553 - loss: 0.7477 - val_accuracy: 0.5125 - val_f1_score: 0.6777 - val_loss: 0.7432 - learning_rate: 1.4058e-04
# Epoch 47/200
# 36/36 - 1s - 35ms/step - accuracy: 0.4983 - f1_score: 0.6412 - loss: 0.7460 - val_accuracy: 0.5125 - val_f1_score: 0.6777 - val_loss: 0.7433 - learning_rate: 1.2302e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step
# oldB → Fold 20 Val F1 = 0.6833
#
# >>> Training model1 on Fold 20
# Epoch 1/200
# 36/36 - 25s - 706ms/step - accuracy: 0.5100 - f1_score: 0.5230 - loss: 0.6940 - val_accuracy: 0.4875 - val_f1_score: 0.0000e+00 - val_loss: 0.6941 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 -
- learning_rate: 0.0010
# Epoch 2/200
# 36/36 - 1s - 22ms/step - accuracy: 0.5148 - f1_score: 0.5222 - loss: 1.6340 - val_accuracy: 0.5125 - val_f1_score: 0.5412 - val_loss: 2.5302 - learning_rate: 9.9994e-04
# Epoch 3/200
# 36/36 - 1s - 20ms/step - accuracy: 0.4991 - f1_score: 0.4735 - loss: 1.6435 - val_accuracy: 0.4750 - val_f1_score: 0.3636 - val_loss: 1.7315 - learning_rate: 9.9969e-04
# Epoch 4/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5208 - f1_score: 0.5225 - loss: 1.0667 - val_accuracy: 0.5000 - val_f1_score: 0.4872 - val_loss: 2.6843 - learning_rate: 9.9914e-04
# Epoch 5/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5217 - f1_score: 0.5098 - loss: 1.2609 - val_accuracy: 0.4750 - val_f1_score: 0.5227 - val_loss: 2.8485 - learning_rate: 9.9815e-04
# Epoch 6/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5282 - f1_score: 0.5480 - loss: 0.8785 - val_accuracy: 0.5125 - val_f1_score: 0.5895 - val_loss: 2.9065 - learning_rate: 9.9661e-04
# Epoch 7/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5382 - f1_score: 0.5288 - loss: 0.8888 - val_accuracy: 0.4375 - val_f1_score: 0.5161 - val_loss: 1.5394 - learning_rate: 9.9440e-04
# Epoch 8/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5525 - f1_score: 0.5468 - loss: 0.7798 - val_accuracy: 0.4750 - val_f1_score: 0.0455 - val_loss: 2.8989 - learning_rate: 9.9140e-04
# Epoch 9/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5278 - f1_score: 0.5417 - loss: 0.9217 - val_accuracy: 0.5125 - val_f1_score: 0.5618 - val_loss: 1.3443 - learning_rate: 9.8749e-04
# Epoch 10/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5434 - f1_score: 0.5418 - loss: 0.8088 - val_accuracy: 0.4875 - val_f1_score: 0.5773 - val_loss: 1.2665 - learning_rate: 9.8256e-04
# Epoch 11/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5530 - f1_score: 0.5576 - loss: 0.7639 - val_accuracy: 0.4625 - val_f1_score: 0.3944 - val_loss: 1.2549 - learning_rate: 9.7652e-04
# Epoch 12/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5304 - f1_score: 0.5356 - loss: 0.8080 - val_accuracy: 0.5125 - val_f1_score: 0.6061 - val_loss: 1.2210 - learning_rate: 9.6924e-04
# Epoch 13/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5425 - f1_score: 0.5663 - loss: 0.7804 - val_accuracy: 0.4750 - val_f1_score: 0.0000e+00 - val_loss: 2.5050 - learning_rate: 9.6066e-04
# Epoch 14/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5412 - f1_score: 0.5374 - loss: 0.7831 - val_accuracy: 0.5125 - val_f1_score: 0.3390 - val_loss: 1.1158 - learning_rate: 9.5068e-04
# Epoch 15/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5469 - f1_score: 0.5887 - loss: 0.7370 - val_accuracy: 0.5000 - val_f1_score: 0.5000 - val_loss: 2.3836 - learning_rate: 9.3923e-04
# Epoch 16/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5660 - f1_score: 0.5777 - loss: 0.7479 - val_accuracy: 0.4625 - val_f1_score: 0.0851 - val_loss: 3.1879 - learning_rate: 9.2626e-04
# Epoch 17/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5543 - f1_score: 0.6005 - loss: 0.7474 - val_accuracy: 0.4750 - val_f1_score: 0.1923 - val_loss: 1.3636 - learning_rate: 9.1171e-04
# Epoch 18/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5495 - f1_score: 0.5986 - loss: 0.7670 - val_accuracy: 0.4375 - val_f1_score: 0.3478 - val_loss: 1.5663 - learning_rate: 8.9555e-04
# Epoch 19/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5638 - f1_score: 0.5814 - loss: 0.7732 - val_accuracy: 0.4500 - val_f1_score: 0.2143 - val_loss: 1.2160 - learning_rate: 8.7777e-04
# Epoch 20/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5564 - f1_score: 0.5521 - loss: 0.7398 - val_accuracy: 0.4500 - val_f1_score: 0.1538 - val_loss: 1.5324 - learning_rate: 8.5837e-04
# Epoch 21/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5747 - f1_score: 0.6148 - loss: 0.7236 - val_accuracy: 0.5125 - val_f1_score: 0.1333 - val_loss: 1.3277 - learning_rate: 8.3736e-04
# Epoch 22/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5378 - f1_score: 0.5384 - loss: 0.7525 - val_accuracy: 0.4875 - val_f1_score: 0.0465 - val_loss: 1.8886 - learning_rate: 8.1479e-04
# Epoch 23/200
# 36/36 - 1s - 22ms/step - accuracy: 0.5451 - f1_score: 0.5808 - loss: 0.7340 - val_accuracy: 0.5125 - val_f1_score: 0.2041 - val_loss: 1.7400 - learning_rate: 7.9071e-04
# Epoch 24/200
# 36/36 - 1s - 21ms/step - accuracy: 0.5729 - f1_score: 0.5852 - loss: 0.6833 - val_accuracy: 0.4750 - val_f1_score: 0.0000e+00 - val_loss: 3.3069 - learning_rate: 7.6518e-04
# Epoch 25/200
# 36/36 - 1s - 23ms/step - accuracy: 0.5707 - f1_score: 0.5829 - loss: 0.7012 - val_accuracy: 0.5125 - val_f1_score: 0.4800 - val_loss: 0.9394 - learning_rate: 7.3832e-04
# Epoch 26/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5825 - f1_score: 0.6300 - loss: 0.7074 - val_accuracy: 0.4750 - val_f1_score: 0.0455 - val_loss: 1.5441 - learning_rate: 7.1022e-04
# Epoch 27/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5538 - f1_score: 0.5801 - loss: 0.6974 - val_accuracy: 0.4500 - val_f1_score: 0.0435 - val_loss: 1.5606 - learning_rate: 6.8101e-04
# Epoch 28/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5638 - f1_score: 0.5729 - loss: 0.6848 - val_accuracy: 0.5000 - val_f1_score: 0.1304 - val_loss: 1.8773 - learning_rate: 6.5084e-04
# Epoch 29/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5642 - f1_score: 0.5810 - loss: 0.6743 - val_accuracy: 0.5625 - val_f1_score: 0.3636 - val_loss: 1.4881 - learning_rate: 6.1987e-04
# Epoch 30/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5729 - f1_score: 0.5820 - loss: 0.6802 - val_accuracy: 0.4875 - val_f1_score: 0.0000e+00 - val_loss: 2.3459 - learning_rate: 5.8827e-04
# Epoch 31/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5773 - f1_score: 0.5975 - loss: 0.6810 - val_accuracy: 0.4625 - val_f1_score: 0.2456 - val_loss: 1.8371 - learning_rate: 5.5621e-04
# Epoch 32/200
# 36/36 - 1s - 20ms/step - accuracy: 0.5621 - f1_score: 0.5883 - loss: 0.6691 - val_accuracy: 0.4750 - val_f1_score: 0.1600 - val_loss: 1.8031 - learning_rate: 5.2388e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# model2 → Fold 20 Val F1 = 0.6061
#
# >>> Training model3 on Fold 20
# Epoch 1/200
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_19/3644324680.py in <cell line: 0>()
#     184
#     185         # Train model
# --> 186         history = model.fit(
#     187             train_gen,
#     188             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57       e.message += " name: " + name
#      58     raise core._status_to_exception(e) from None
# ---> 59   except TypeError as e:
#      60     keras_symbolic_tensors = [x for x in inputs if _is_keras_symbolic_tensor(x)]
#      61     if keras_symbolic_tensors:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/tmp/ipykernel_19/3644324680.py", line 186, in <cell line: 0>
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 371, in fit
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 219, in function
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 132, in multi_step_on_iterator
#
# Out of memory while trying to allocate 958551496 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_3628133]
