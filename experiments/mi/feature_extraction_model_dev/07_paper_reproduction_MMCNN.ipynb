# %%
# !git clone https://github.com/YousefEldaly/ECML-PKDD_MMCNN
# Out:
# Cloning into 'ECML-PKDD_MMCNN'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 258 (delta 7), reused 0 (delta 0), pack-reused 243 (from 2)
# Receiving objects: 100% (258/258), 82.81 MiB | 23.44 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Updating files: 100% (138/138), done.

# %%
cd /kaggle/working/ECML-PKDD_MMCNN
# Out:
# /kaggle/working/ECML-PKDD_MMCNN

# %%
# !python main.py --get2bpath bci2b-npy/
# Out:
# 2025-06-23 08:42:07.497056: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750668127.768306      49 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750668127.844554      49 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# A01T load success.
# A01E load success.
# A02T load success.
# A02E load success.
# A03T load success.
# A03E load success.
# A04T load success.
# A04E load success.
# A05T load success.
# A05E load success.
# A06T load success.
# A06E load success.
# A07T load success.
# A07E load success.
# A08T load success.
# A08E load success.
# ...
